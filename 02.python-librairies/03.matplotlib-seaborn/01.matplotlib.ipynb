# %% [markdown]
# ## **Matplotlib :** Overview
#
# #### _Fondamentaux sur la librairie Matplotlib_
#
# 🟠 `on work`
#
# ---
#
# 1. **Composants**
#     * ..

# %% [markdown]
# **Libraries**

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ---
# ### **1.**

# %% [markdown]
# ##### **1.1** -

# %%
# Dessiner un graphique
plt.plot([1, 6, 4, 9, 7, 8])

# %% [markdown]
# ## **Preparation :** Cleaning
#
# #### _Nettoyage des données pour le Machine Learning_
#
# 🟠 `on work`
#
# ---
#
# 1. **Vérifications**
#     * Valeurs manquantes
#     * Types de valeurs
#     * Pertience des valeurs
#     * Valeurs dupliquées
#
# `---`
#
# * [DataQuest :: Data Preparation for Machine Learning](https://www.dataquest.io/blog/machine-learning-preparing-data/)
# * [Elite DataScience :: Pandas Content for Cleaning](https://elitedatascience.com/python-cheat-sheet)
# * [Kaggle :: Handling Missing Values](https://www.kaggle.com/code/rtatman/data-cleaning-challenge-handling-missing-values/notebook)
# * [Kaggle :: Preliminary Data Cleaning](https://www.kaggle.com/code/quannguyen135/preliminary-data-cleaning-with-python/notebook)

# %% [markdown]
# **Built-in**

# %% [markdown]
# **Librairies**

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# **Notebook setup**

# %%
# Pandas
pd.options.display.max_rows = 30
pd.options.display.min_rows = 6

# %% [markdown]
# **NYC Squirrels dataset**
#
# [NYC Squirrels from Open Data](https://opendata.cityofnewyork.us/)

# %%
squirrels_file_path = '../_datasets/nyc_squirrels_data.csv'
sqrl_data = pd.read_csv(squirrels_file_path)

sqrl_data
# Out:
#               X          Y Unique Squirrel ID Hectare Shift      Date  \
# 0    -73.956134  40.794082     37F-PM-1014-03     37F    PM  10142018
# 1    -73.957044  40.794851     37E-PM-1006-03     37E    PM  10062018
# 2    -73.976831  40.766718      2E-AM-1010-03     02E    AM  10102018
# ...         ...        ...                ...     ...   ...       ...
# 3020 -73.966587  40.783678     22D-PM-1012-07     22D    PM  10122018
# 3021 -73.963994  40.789915     29B-PM-1010-02     29B    PM  10102018
# 3022 -73.975479  40.769640      5E-PM-1012-01     05E    PM  10122018
#
#       Hectare Squirrel Number    Age Primary Fur Color  \
# 0                           3    NaN               NaN
# 1                           3  Adult              Gray
# 2                           3  Adult          Cinnamon
# ...                       ...    ...               ...
# 3020                        7  Adult              Gray
# 3021                        2    NaN              Gray
# ...

# %% [markdown]
# ---
# ### **1.** Vérifications

# %% [markdown]
# ##### **1.1** - Valeurs manquanes

# %% [markdown]
# ##### **1.2** - Types de valeurs

# %% [markdown]
# ##### **1.3** - Pertinence des valeurs

# %% [markdown]
# ##### **1.4** - Valeurs dupliquées
